# %% [markdown]
# # **Variables**

# %%
age = 22 #Integer Variable
cgpa = 3.56 # Float Variable
name = "Muhammad Ahmad" # String Variable

# %% [markdown]
# # **Print Statements**

# %%
print("My name is: ",name)
print("My age is: ", age)
print("My CGPA is: ", cgpa)
# Out:
# My name is:  Muhammad Ahmad
# My age is:  22
# My CGPA is:  3.56

# %% [markdown]
# # **List**

# %%
list1 = ["apple", "bat", "cat"]
list2 = [3, 4, 5, 6, 10]
list3 = [3.56, 4.54, 324.342]

# %%
print(list1, '\n', list2, '\n', list3)
# Out:
# ['apple', 'bat', 'cat']
#  [3, 4, 5, 6, 10]
#  [3.56, 4.54, 324.342]

# %% [markdown]
# # **Dictionary**

# %%
student = {
    "name":"Muhammad",
    "age":22,
    "cgpa":3.56
}

# %%
print(student)
# Out:
# {'name': 'Muhammad', 'age': 22, 'cgpa': 3.56}

# %%
print(student["name"])
# Out:
# Muhammad

# %% [markdown]
# # **Sets**

# %%
set1 = {1,23,2,2,34,43,3,3,4,5,5,7,5,32,}
print(set1)
# Out:
# {32, 1, 2, 3, 34, 4, 5, 7, 43, 23}

# %% [markdown]
# # **Tuples**

# %%
tuple1 = (12, 23, 34, 343, 34)
print(tuple1)
# Out:
# (12, 23, 34, 343, 34)
